# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
image='D:/pythonCode/projects/Fundus/1000images/29.1.Blur fundus with suspected PDR/1ffa9686-8d87-11e8-9daf-6045cb817f5b..JPG'

# %%
im=cv2.imread("D:/pythonCode/projects/multimediaproject/dataset/train/high_res/0.png",cv2.IMREAD_ANYCOLOR)
im_rgb=cv2.cvtColor(im,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(im_rgb)

# %%
im_rgb=cv2.resize(im_rgb,[700,600])

# %%
plt.imshow(im_rgb)

# %%
cv2.imwrite('edit.JPG',cv2.cvtColor(im_rgb, cv2.COLOR_BGR2RGB))
# Out:
# True
